# %%
import pandas as pd
df = pd.read_csv("Datasets/direct_marketing.csv")

# %%
df.head(5)
# Out:
#    recency history_segment  history  mens  womens   zip_code  newbie channel  \
# 0       10  2) $100 - $200   142.44     1       0  Surburban       0   Phone
# 1        6  3) $200 - $350   329.08     1       1      Rural       1     Web
# 2        7  2) $100 - $200   180.65     0       1  Surburban       1     Web
# 3        9  5) $500 - $750   675.83     1       0      Rural       1     Web
# 4        2    1) $0 - $100    45.34     1       0      Urban       0     Web
#
#          segment  visit  conversion  spend  DM_category
# 0  Womens E-Mail      0           0    0.0            4
# 1      No E-Mail      0           0    0.0           11
# 2  Womens E-Mail      0           0    0.0            1
# 3    Mens E-Mail      0           0    0.0            2
# 4  Womens E-Mail      0           0    0.0            4

# %%
df.iloc[50:101,:]
# Out:
#      recency   history_segment  history  mens  womens   zip_code  newbie  \
# 50         3    3) $200 - $350   203.30     0       1  Surburban       0
# 51         9    2) $100 - $200   185.43     1       0      Urban       0
# 52         7      1) $0 - $100    29.99     0       1      Urban       1
# 53         9      1) $0 - $100    78.62     1       0      Urban       0
# 54        12    2) $100 - $200   150.06     0       1  Surburban       0
# 55         6      1) $0 - $100    42.66     1       0  Surburban       0
# 56        12      1) $0 - $100    69.08     0       1      Rural       0
# 57         3    5) $500 - $750   549.29     1       0  Surburban       1
# 58         9    5) $500 - $750   506.83     1       0      Rural       1
# 59         3    2) $100 - $200   143.93     0       1  Surburban       0
# 60        10    2) $100 - $200   115.40     1       0      Urban       0
# 61         2      1) $0 - $100    96.91     1       0  Surburban       0
# ...

# %% [markdown]
# ### list of all men and women with recency < 7

# %%
df.head(5)
# Out:
#    recency history_segment  history  mens  womens   zip_code  newbie channel  \
# 0       10  2) $100 - $200   142.44     1       0  Surburban       0   Phone
# 1        6  3) $200 - $350   329.08     1       1      Rural       1     Web
# 2        7  2) $100 - $200   180.65     0       1  Surburban       1     Web
# 3        9  5) $500 - $750   675.83     1       0      Rural       1     Web
# 4        2    1) $0 - $100    45.34     1       0      Urban       0     Web
#
#          segment  visit  conversion  spend  DM_category
# 0  Womens E-Mail      0           0    0.0            4
# 1      No E-Mail      0           0    0.0           11
# 2  Womens E-Mail      0           0    0.0            1
# 3    Mens E-Mail      0           0    0.0            2
# 4  Womens E-Mail      0           0    0.0            4

# %%
df_slice = df.loc[:,['recency','mens','womens']]
df_dice = df_slice[df_slice.recency < 7]
df_dice[df_dice.recency == 1]
# Out:
#        recency  mens  womens
# 11           1     0       1
# 36           1     0       1
# 44           1     0       1
# 47           1     1       1
# 66           1     0       1
# 75           1     0       1
# 84           1     0       1
# 97           1     0       1
# 98           1     0       1
# 119          1     0       1
# 123          1     0       1
# 124          1     1       0
# 127          1     0       1
# 133          1     0       1
# 152          1     1       1
# 159          1     1       0
# 161          1     1       0
# 162          1     0       1
# 163          1     0       1
# 168          1     0       1
# 172          1     1       1
# 189          1     1       1
# 192          1     1       0
# 196          1     0       1
# 202          1     1       0
# 204          1     1       0
# 208          1     1       0
# 215          1     1       0
# 219          1     0       1
# 224          1     0       1
# ...        ...   ...     ...
# ...

# %%
import pandas as pd
df = pd.read_csv("Datasets/direct_marketing.csv")
df_recency = df[['recency']].describe()
